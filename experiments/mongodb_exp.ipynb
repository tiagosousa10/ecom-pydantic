# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://tiagosousatams_db_user:KN1igRSdIXxLgqu8@ecom-pydantic.tfiwfj4.mongodb.net/?appName=ecom-pydantic")

# %%
db = client["ecom_db"]

collection = db["order_products"]

print("connected to mongodb")
# Out:
# connected to mongodb

# %%
product = [
    {
    "name": "Men Casual Shirt",
    "price": 999,
    "category": "men"
},
{
    "name": "Women Casual Shirt",
    "price": 999,
    "category": "women"
},
{
    "name": "Kids Casual Shirt",
    "price": 999,
    "category": "kids"
}
]

collection.insert_many(product)
# Out:
# InsertManyResult([ObjectId('69f0df116174b777f01f74e3'), ObjectId('69f0df116174b777f01f74e4'), ObjectId('69f0df116174b777f01f74e5')], acknowledged=True)

# %%
all_products =collection.find()
for product in all_products:
    print(product)
# Out:
# {'_id': ObjectId('69f0df116174b777f01f74e3'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('69f0df116174b777f01f74e4'), 'name': 'Women Casual Shirt', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69f0df116174b777f01f74e5'), 'name': 'Kids Casual Shirt', 'price': 999, 'category': 'kids'}

# %%
product = collection.find_one({"price": 999})
print(product)
print("--------------------------------")

men_products = collection.find({"category": "men"})
for product in men_products:
    print(product)
# Out:
# {'_id': ObjectId('69f0df116174b777f01f74e3'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# --------------------------------
# {'_id': ObjectId('69f0df116174b777f01f74e3'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}

# %%
collection.update_one({"name": "Men Casual Shirt"}, {"$set": {"price": 1000}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000068'), 'opTime': {'ts': Timestamp(1777393426, 4), 't': 104}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1777393426, 4), 'signature': {'hash': b'~z\x89X\xa1Q1\xc5N\x90\xb4z4w\xcd\x7f\x0e#*L', 'keyId': 7573793682508218369}}, 'operationTime': Timestamp(1777393426, 4), 'updatedExisting': True}, acknowledged=True)

# %%
men_products = collection.find({"category": "men"})
for product in men_products:
    print(product)
# Out:
# {'_id': ObjectId('69f0df116174b777f01f74e3'), 'name': 'Men Casual Shirt', 'price': 1000, 'category': 'men'}

# %%
collection.delete_one({"name": "Men Casual Shirt"})

print("Product deleted")
# Out:
# Product deleted

# %%
collection.delete_many({})

print("All products deleted")
# Out:
# All products deleted
